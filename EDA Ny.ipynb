# %%
import pandas as pd
import numpy as np
import seaborn as sns
# sns.set_theme(style="whitegrid", palette="pastel")
sns.light_palette("#79C")
from matplotlib import pyplot as plt

# %%
df_2020 = pd.read_excel('ny_health_2020.xlsx')
df_2020.shape
# Out:
# (8781, 143)

# %%
df_2019 = pd.read_excel('ny_health_2019.xlsx')
df_2019.shape
# Out:
# (8803, 153)

# %% [markdown]
# ## Filtering and Renaming Columns

# %%
df_2020.index
# Out:
# RangeIndex(start=0, stop=8781, step=1)

# %%
df_2019.index
# Out:
# RangeIndex(start=0, stop=8803, step=1)

# %%
df_2020 = df_2020[ ['mood1','agegroup', 'birthsex','imputed_povgroup3','generalhealth', 'insured', 'insure20r', 'delaypayrent', 'smoker', 'education',
'everhivtest20', 'sexuallyactive20', 'drinker', 'bmi', 'usborn', 'employment20', 'k6', 'nsugardrinkperday20','exercise20', 'toldhighbp20', 'child']]

# %%
df_2020.rename(columns={
    'insure20r': 'insure', 'everhivtest20': 'everhivtest','sexuallyactive20': 'sexuallyactive', 'employment20': 'employment',
    'nsugardrinkperday20': 'nsugardrinkperday', 'exercise20': 'exercise','toldhighbp20': 'toldhighbp'}, inplace=True)

# %%
df_2019 = df_2019[ ['mood1','agegroup', 'birthsex','imputed_povgroup3','generalhealth', 'insured', 'insure19r', 'delaypayrent', 'smoker', 'education',
'everhivtest19', 'sexuallyactive19', 'drinker', 'bmi', 'usborn', 'employment19', 'k6', 'nsugardrinkperday19','exercise19', 'toldhighbp19', 'child']]

# %%
df_2019.rename(columns={
    'insure19r': 'insure', 'everhivtest19': 'everhivtest','sexuallyactive19': 'sexuallyactive', 'employment19': 'employment',
    'nsugardrinkperday19': 'nsugardrinkperday', 'exercise19': 'exercise','toldhighbp19': 'toldhighbp'}, inplace=True)

# %%
df = pd.concat([df_2020, df_2019], ignore_index=True)

# %%
df.shape
# Out:
# (17584, 21)

# %%
df.head()
# Out:
#    mood1  agegroup  birthsex  imputed_povgroup3  generalhealth  insured  \
# 0      5       4.0       2.0                  1            3.0      1.0
# 1      5       4.0       2.0                  1            4.0      1.0
# 2      5       3.0       2.0                  3            2.0      1.0
# 3      5       2.0       2.0                  1            2.0      2.0
# 4      5       3.0       2.0                  3            3.0      1.0
#
#    insure  delaypayrent  smoker  education  ...  sexuallyactive  drinker  \
# 0     4.0           2.0     1.0        4.0  ...             2.0      2.0
# 1     3.0           2.0     1.0        1.0  ...             2.0      2.0
# 2     1.0           2.0     1.0        4.0  ...             1.0      2.0
# 3     6.0           1.0     1.0        3.0  ...             1.0      2.0
# 4     1.0           2.0     1.0        3.0  ...             1.0      1.0
#
#          bmi  usborn  employment  k6  nsugardrinkperday  exercise  toldhighbp  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17584 entries, 0 to 17583
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mood1              17584 non-null  int64
#  1   agegroup           17554 non-null  float64
#  2   birthsex           17525 non-null  float64
#  3   imputed_povgroup3  17584 non-null  int64
#  4   generalhealth      17537 non-null  float64
#  5   insured            17092 non-null  float64
#  6   insure             17092 non-null  float64
#  7   delaypayrent       17430 non-null  float64
#  8   smoker             17506 non-null  float64
#  9   education          17494 non-null  float64
#  10  everhivtest        17077 non-null  float64
#  11  sexuallyactive     15975 non-null  float64
#  12  drinker            17429 non-null  float64
#  13  bmi                16863 non-null  float64
#  14  usborn             17499 non-null  float64
# ...

# %%
sns.set_style("ticks")
# sns.pairplot(df,diag_kind = "kde",kind = "scatter",palette = "husl")

# %%
sns.light_palette("#79C")
# sns.countplot(df, x="education", hue="imputed_povgroup3", stat="percent")
# Out:
# [(0.9416189672416196, 0.943616042212052, 0.9476594498033685),
#  (0.8466285071266291, 0.8748928337696416, 0.9181275598426948),
#  (0.7516380470116384, 0.8061696253272311, 0.8885956698820211),
#  (0.6566475868966479, 0.7374464168848208, 0.8590637799213474),
#  (0.5616571267816572, 0.6687232084424104, 0.8295318899606737),
#  (0.4666666666666667, 0.6, 0.8)]

# %% [markdown]
# ## Health

# %%
sns.displot(df, x="bmi", hue="mood1", discrete=True)

# %%
sns.countplot(df, x="mood1", hue="imputed_povgroup3", stat="percent")
# Out:
# <Axes: xlabel='mood1', ylabel='percent'>

# %%
sns.displot(df, x="bmi", hue ="exercise")

# %%
sns.scatterplot(data = df, x="bmi", y="nsugardrinkperday", hue="usborn")
# Out:
# <Axes: xlabel='bmi', ylabel='nsugardrinkperday'>

# %% [markdown]
# ## Drinking

# %%
plt.title('Told High Blood Pressure')
sns.countplot(data=df, x='drinker', hue="toldhighbp")
# Out:
# <Axes: title={'center': 'Told High Blood Pressure'}, xlabel='drinker', ylabel='count'>

# %%
sns.countplot(df, x="mood1", hue="drinker", stat="percent")
# Out:
# <Axes: xlabel='mood1', ylabel='percent'>

# %%
sns.countplot(df, x="insure", hue="drinker", stat="percent")
# Out:
# <Axes: xlabel='insure', ylabel='percent'>

# %%
plt.figure(figsize=(10, 6))
plt.title('K6 with Drinking (2020)', fontsize=16, fontweight='bold', pad=10)
sns.countplot(df, x="k6", hue="drinker")
# Out:
# <Axes: title={'center': 'K6 with Drinking (2020)'}, xlabel='k6', ylabel='count'>

# %%
plt.figure(figsize=(10, 6))
plt.title('K6 with Drinking (2019)', fontsize=16, fontweight='bold', pad=10)
sns.countplot(df_2019, x="k6", hue="drinker")
# Out:
# <Axes: title={'center': 'K6 with Drinking (2019)'}, xlabel='k6', ylabel='count'>

# %% [markdown]
# # Data pre processing

# %%
## fix missing values
df.fillna(method='ffill', inplace=True)
# Out:
# /var/folders/0b/bd08tdvx0zq93j7tbbzdnmt00000gn/T/ipykernel_12269/2440772003.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17584 entries, 0 to 17583
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   mood1              17584 non-null  int64
#  1   agegroup           17584 non-null  float64
#  2   birthsex           17584 non-null  float64
#  3   imputed_povgroup3  17584 non-null  int64
#  4   generalhealth      17584 non-null  float64
#  5   insured            17584 non-null  float64
#  6   insure             17584 non-null  float64
#  7   delaypayrent       17584 non-null  float64
#  8   smoker             17584 non-null  float64
#  9   education          17584 non-null  float64
#  10  everhivtest        17584 non-null  float64
#  11  sexuallyactive     17584 non-null  float64
#  12  drinker            17584 non-null  float64
#  13  bmi                17584 non-null  float64
#  14  usborn             17584 non-null  float64
# ...

# %%
df.head()
# Out:
#    mood1  agegroup  birthsex  imputed_povgroup3  generalhealth  insured  \
# 0      5       4.0       2.0                  1            3.0      1.0
# 1      5       4.0       2.0                  1            4.0      1.0
# 2      5       3.0       2.0                  3            2.0      1.0
# 3      5       2.0       2.0                  1            2.0      2.0
# 4      5       3.0       2.0                  3            3.0      1.0
#
#    insure  delaypayrent  smoker  education  ...  sexuallyactive  drinker  \
# 0     4.0           2.0     1.0        4.0  ...             2.0      2.0
# 1     3.0           2.0     1.0        1.0  ...             2.0      2.0
# 2     1.0           2.0     1.0        4.0  ...             1.0      2.0
# 3     6.0           1.0     1.0        3.0  ...             1.0      2.0
# 4     1.0           2.0     1.0        3.0  ...             1.0      1.0
#
#          bmi  usborn  employment  k6  nsugardrinkperday  exercise  toldhighbp  \
# ...

# %%
# 1–6 = mild, 7–12 = moderate, 13–24 = severe
def categorize_k6(value):
    if value >= 0 and value <= 6:
        return 1 #
    elif value >= 7 and value <= 12:
        return 2 #moderate
    else: return 3

# %%
df['k6_category'] = df['k6'].apply(categorize_k6)

# %%
sns.countplot(df, x="k6_category")
# Out:
# <Axes: xlabel='k6_category', ylabel='count'>

# %% [markdown]
# ## balance the data set

# %%
df['k6_category'].value_counts()
# Out:
# k6_category
# 1    13563
# 2     3042
# 3      979
# Name: count, dtype: int64

# %%
result1 = df[df['k6_category'] == 1][:5000]
result2 = df[df['k6_category'] == 2]
result3 = df[df['k6_category'] == 3]
df = pd.concat([result1, result2, result3], ignore_index=True)
df.shape
# Out:
# (9021, 22)

# %%
sns.countplot(df, x="k6_category")
# Out:
# <Axes: xlabel='k6_category', ylabel='count'>

# %%
df_copy = df.copy()
df_copy['birthsex'] = np.where(df_copy['birthsex'] == 2, 1, 0)
df_copy['insured'] = np.where(df_copy['insured'] == 1, 1, 0)
df_copy['delaypayrent'] = np.where(df['delaypayrent'] == 1, 1, 0)
df_copy['everhivtest'] = np.where(df['everhivtest'] == 1, 1, 0)
df_copy['sexuallyactive'] = np.where(df['sexuallyactive'] == 1, 1, 0)
df_copy['drinker'] = np.where(df['drinker'] == 1, 1, 0)
df_copy['usborn'] = np.where(df['usborn'] == 1, 1, 0)
df_copy['exercise'] = np.where(df['exercise'] == 1, 1, 0)
# df_copy['regularrx'] = np.where(df['regularrx'] == 1, 1, 0)
df_copy['toldhighbp'] = np.where(df['toldhighbp'] == 1, 1, 0)

# %% [markdown]
# # one hot encoding on categorical values

# %%
df_encoded = pd.get_dummies(df_copy, columns=['mood1', 'agegroup', 'imputed_povgroup3', 'generalhealth', 'smoker', 'education', 'employment'])

# %%
df_encoded.drop(['k6'], inplace=True, axis=1)

# %%
df_encoded.head()
# Out:
#    birthsex  insured  insure  delaypayrent  everhivtest  sexuallyactive  \
# 0         1        1     4.0             0            0               0
# 1         1        1     3.0             0            1               0
# 2         1        1     1.0             0            0               1
# 3         1        0     6.0             1            0               1
# 4         1        1     1.0             0            1               1
#
#    drinker        bmi  usborn  nsugardrinkperday  ...  education_3.0  \
# 0        0  23.855321       0           1.000000  ...          False
# 1        0  23.911565       1           0.285714  ...          False
# 2        0  23.911565       1           0.000000  ...          False
# 3        0  22.312012       1           0.033058  ...           True
# 4        1  35.505051       1           0.000000  ...           True
#
#    education_4.0  employment_1.0  employment_2.0  employment_3.0  \
# ...

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9021 entries, 0 to 9020
# Data columns (total 46 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   birthsex             9021 non-null   int64
#  1   insured              9021 non-null   int64
#  2   insure               9021 non-null   float64
#  3   delaypayrent         9021 non-null   int64
#  4   everhivtest          9021 non-null   int64
#  5   sexuallyactive       9021 non-null   int64
#  6   drinker              9021 non-null   int64
#  7   bmi                  9021 non-null   float64
#  8   usborn               9021 non-null   int64
#  9   nsugardrinkperday    9021 non-null   float64
#  10  exercise             9021 non-null   int64
#  11  toldhighbp           9021 non-null   int64
#  12  child                9021 non-null   float64
#  13  k6_category          9021 non-null   int64
#  14  mood1_1              9021 non-null   bool
# ...

# %% [markdown]
# # Model Building and Evaluations

# %%
df_encoded.columns
# Out:
# Index(['birthsex', 'insured', 'insure', 'delaypayrent', 'everhivtest',
#        'sexuallyactive', 'drinker', 'bmi', 'usborn', 'nsugardrinkperday',
#        'exercise', 'toldhighbp', 'child', 'k6_category', 'mood1_1', 'mood1_2',
#        'mood1_3', 'mood1_4', 'mood1_5', 'agegroup_1.0', 'agegroup_2.0',
#        'agegroup_3.0', 'agegroup_4.0', 'imputed_povgroup3_1',
#        'imputed_povgroup3_2', 'imputed_povgroup3_3', 'generalhealth_1.0',
#        'generalhealth_2.0', 'generalhealth_3.0', 'generalhealth_4.0',
#        'generalhealth_5.0', 'smoker_1.0', 'smoker_2.0', 'smoker_3.0',
#        'education_1.0', 'education_2.0', 'education_3.0', 'education_4.0',
#        'employment_1.0', 'employment_2.0', 'employment_3.0', 'employment_4.0',
#        'employment_5.0', 'employment_6.0', 'employment_7.0', 'employment_8.0'],
#       dtype='object')

# %%
df_encoded['k6_category'].unique()
# Out:
# array([1, 2, 3])

# %%
X = df_encoded[['birthsex', 'insured', 'delaypayrent', 'everhivtest',
       'sexuallyactive', 'drinker', 'bmi', 'usborn', 'nsugardrinkperday',
       'exercise', 'toldhighbp', 'mood1_1',
       'mood1_2', 'mood1_3', 'mood1_4', 'mood1_5', 'agegroup_1.0',
       'agegroup_2.0', 'agegroup_3.0', 'agegroup_4.0', 'imputed_povgroup3_1',
       'imputed_povgroup3_2', 'imputed_povgroup3_3', 'generalhealth_1.0',
       'generalhealth_2.0', 'generalhealth_3.0', 'generalhealth_4.0',
       'generalhealth_5.0', 'smoker_1.0', 'smoker_2.0',
       'smoker_3.0', 'education_1.0', 'education_2.0', 'education_3.0',
       'education_4.0','employment_1.0', 'employment_2.0', 'employment_3.0', 'employment_4.0',
       'employment_5.0', 'employment_6.0', 'employment_7.0', 'employment_8.0']]
y = df_encoded['k6_category']

# %%
from sklearn import linear_model
from sklearn.ensemble import RandomForestClassifier
import statsmodels.api as sm
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay, f1_score, classification_report
from sklearn.model_selection import RandomizedSearchCV, train_test_split

# %%
def build_and_test_models(X_train, X_test, y_train, y_test):
    dic = {
    'Logistic Regression' : linear_model.LogisticRegression(max_iter=5000),
    'Random Forest': RandomForestClassifier(),
    'SGD Classifier': linear_model.SGDClassifier()
    }

    for name, model in dic.items():
        print('Training...', name )
        model.fit(X_train, y_train)
        prediction = model.predict(X_test)
        accuracy = accuracy_score(y_test, prediction)
        F1 = f1_score(y_test, prediction, average='micro')
        print('accuracy', accuracy, ' F1: ', F1)
        # Create the confusion matrix
        cm = confusion_matrix(y_test, prediction)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm)
        print(classification_report(y_test, prediction))
        disp.plot()
        plt.title(name)  # You can customize the title text here
        # Show the plot
        plt.show()

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
build_and_test_models(X_train, X_test, y_train, y_test)
# Out:
# Training... Logistic Regression
# accuracy 0.7684210526315789  F1:  0.7684210526315789
#               precision    recall  f1-score   support
#
#            1       0.86      0.85      0.85      1046
#            2       0.64      0.71      0.67       578
#            3       0.69      0.51      0.59       181
#
#     accuracy                           0.77      1805
#    macro avg       0.73      0.69      0.70      1805
# weighted avg       0.77      0.77      0.77      1805
# Training... Random Forest
# accuracy 0.7490304709141274  F1:  0.7490304709141274
#               precision    recall  f1-score   support
#
#            1       0.84      0.84      0.84      1046
#            2       0.62      0.66      0.64       578
#            3       0.63      0.51      0.57       181
#
#     accuracy                           0.75      1805
#    macro avg       0.70      0.67      0.68      1805
# weighted avg       0.75      0.75      0.75      1805
# Training... SGD Classifier
# ...
